# %%
import mdptoolbox, mdptoolbox.example
import numpy as _np
import scipy.sparse as _sp
y = _np.zeros((2, 3, 4))

# %%
P, R = mdptoolbox.example.rand(10, 3)

# %%
R
# Out:
# array([[[-0.        ,  0.        , -0.22774651, -0.61648912, -0.        ,
#          -0.        ,  0.        , -0.        , -0.07014889, -0.78145019],
#         [ 0.84477012, -0.22142584, -0.16194633, -0.33272044,  0.        ,
#          -0.98605055, -0.07395227,  0.58748968,  0.79338813,  0.97161746],
#         [-0.91399327,  0.37067754,  0.22942862, -0.        ,  0.45552655,
#           0.77898101, -0.        ,  0.        , -0.        ,  0.07386713],
#         [-0.        , -0.        ,  0.        , -0.        ,  0.        ,
#           0.        , -0.        , -0.        , -0.64626659,  0.        ],
#         [ 0.18948885,  0.09772389, -0.44479248, -0.79195026,  0.45965146,
#          -0.28954766,  0.0024423 , -0.85766009, -0.56821225, -0.26824201],
#         [-0.        , -0.97959428,  0.        , -0.        , -0.        ,
#          -0.39786387, -0.        , -0.934448  ,  0.        , -0.        ],
#         [-0.61328778, -0.        ,  0.        , -0.        ,  0.        ,
# ...
